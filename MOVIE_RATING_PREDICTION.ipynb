# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
data=pd.read_csv("/content/ratings_sample.csv")
data
# Out:
#       user_id                     movie_id  rating  \
# 0       93787       gods+and+monsters+1998       4
# 1      197858                stargate+1994       3
# 2       76204               toy+story+1995       3
# 3      667201   friends+with+benefits+2011       4
# 4      336750                 sleeper+1973       4
# ...       ...                          ...     ...
# 1993   584138  the+matrix+revolutions+2003       3
# 1994   440326           koyaanisqatsi+1982       5
# 1995     5132             prt--porter+1994       3
# 1996   764247                    clue+1985       5
# 1997   858562            pulp+fiction+1994       4
#
#                                          genres  \
# 0                                         Drama
# 1              Action Adventure Science Fiction
# 2                       Animation Comedy Family
# 3                                Romance Comedy
# 4                Comedy Romance Science Fiction
# ...                                         ...
# ...

# %%
print(data.head)
print(data.tail)
# Out:
# <bound method NDFrame.head of       user_id                     movie_id  rating  \
# 0       93787       gods+and+monsters+1998       4
# 1      197858                stargate+1994       3
# 2       76204               toy+story+1995       3
# 3      667201   friends+with+benefits+2011       4
# 4      336750                 sleeper+1973       4
# ...       ...                          ...     ...
# 1993   584138  the+matrix+revolutions+2003       3
# 1994   440326           koyaanisqatsi+1982       5
# 1995     5132             prt--porter+1994       3
# 1996   764247                    clue+1985       5
# 1997   858562            pulp+fiction+1994       4
#
#                                          genres  \
# 0                                         Drama
# 1              Action Adventure Science Fiction
# 2                       Animation Comedy Family
# 3                                Romance Comedy
# 4                Comedy Romance Science Fiction
# ...

# %%
print(data.columns)
# Out:
# Index(['user_id', 'movie_id', 'rating', 'genres', 'production_companies',
#        'production_countries', 'release_year', 'overview'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1998 entries, 0 to 1997
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               1998 non-null   int64
#  1   movie_id              1998 non-null   object
#  2   rating                1998 non-null   int64
#  3   genres                1996 non-null   object
#  4   production_companies  1985 non-null   object
#  5   production_countries  1994 non-null   object
#  6   release_year          1998 non-null   float64
#  7   overview              1997 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 125.0+ KB

# %%
data.isnull().sum()
# Out:
# user_id                  0
# movie_id                 0
# rating                   0
# genres                   2
# production_companies    13
# production_countries     4
# release_year             0
# overview                 1
# dtype: int64

# %%
data['genres']=data['genres'].fillna('Drama')
data['production_companies']=data['production_companies'].fillna('Pixar Animation Studios')
#data['genres']=data['genres'].fillna('Drama')

# %%
data.isnull().sum()
# Out:
# user_id                 0
# movie_id                0
# rating                  0
# genres                  0
# production_companies    0
# production_countries    4
# release_year            0
# overview                1
# dtype: int64

# %%
data.describe()
# Out:
#              user_id       rating  release_year
# count    1998.000000  1998.000000   1998.000000
# mean   497375.253253     3.675676   1991.538539
# std    290588.824443     1.056216     13.153585
# min        56.000000     1.000000   1922.000000
# 25%    239382.000000     3.000000   1990.000000
# 50%    490846.000000     4.000000   1995.000000
# 75%    747196.750000     4.000000   1999.000000
# max    998652.000000     5.000000   2014.000000

# %%
dependent_variable = ['release_year',]
independent_variables = ['rating']

train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

X_train = train_data[independent_variables]
y_train = train_data[dependent_variable]

X_test = test_data[independent_variables]
y_test = test_data[dependent_variable]

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('Mean Absolute Error:', mae)
print('R2 Score:', r2)
# Out:
# Mean Squared Error: 151.03843090653785
# Mean Absolute Error: 8.44081630683899
# R2 Score: 0.00915507250573333
